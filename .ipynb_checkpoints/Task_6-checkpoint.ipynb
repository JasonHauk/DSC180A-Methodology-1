# %%
import gzip
import pandas as pd
import pandas_plink as pdpl
import statsmodels.api as sm
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import subprocess
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
# There are three file types for genetic data that interest us
# Multiple different samples of these files can be found on 1000 Genomes
# In the interest of size and reproducibility we will use just EUR.1 in the beginning
bim, fam, G = pdpl.read_plink("EUR.1.test/1000G.EUR.1")

# This file contains the gene expression data we will be using
gene_expr = pd.read_csv('GD462.GeneQuantRPKM.50FN.samplename.resk10.txt.gz', compression='gzip', sep='\t')

# We also want to grab the gene annotations
with gzip.open("gene_annot.txt.gz", "rt") as f:
    # Read the file content into a pandas DataFrame
    gene_annotations = pd.read_csv(f, sep="\t")
# Out:
# Mapping files: 100%|██████████| 3/3 [00:01<00:00,  1.65it/s]

# %%
# We want to combine the files so that we have users as rows, and their snps as columns
geno_df = pd.DataFrame(G.compute().transpose())
geno_df.columns = bim['snp']  # Use SNP IDs as columns
geno_df.index = fam['iid']  # Use individual IDs as rows

# Transpose gene expression data so that individual IDs are in the index as well
gene_expr_t = gene_expr.set_index('Gene_Symbol').transpose()

# The data isn't always consistent across all the files, so we want to only pull data we have all the information for
# Extract the individual IDs that match those in fam['iid']
gene_expr_t.index.name = 'iid'
matching_ids = gene_expr_t.index.intersection(fam['iid'])

# Filter both dataframes to only include these matching IDs
geno_df_filtered = geno_df.loc[matching_ids]
gene_expr_filtered = gene_expr_t.loc[matching_ids]

# %%
# Randomly select a gene to test:
gene_of_interest = 'ENSG00000152931.6'

# Adjust window according to gene location
# [We will automate this process in the next step]
snps_in_window = bim[(bim['chrom'] == "1") & 
                         (bim['pos'] >= 252566) & 
                         (bim['pos'] <= 1252566)]

# Get the SNP IDs from the filtered SNPs
snp_ids = snps_in_window['snp'].values

# Filter the genotype DataFrame for the SNPs in the window
genotype_data_window = geno_df.loc[:, snp_ids]

# Filter both dataframes to only include these matching IDs
geno_df_filtered = genotype_data_window.loc[matching_ids]
gene_expr_filtered = gene_expr_t.loc[matching_ids]

# Filter the gene expression data for the gene of interest
gene_expr_filtered = gene_expr_t.loc[matching_ids, gene_of_interest]

# Merge the gene expression data with genotype data
merged_df = pd.concat([gene_expr_filtered, geno_df_filtered], axis=1)

# Rename the gene expression column for clarity
merged_df.rename(columns={gene_of_interest: 'gene_expression'}, inplace=True)

# Ensure gene expression values are numeric
y = pd.to_numeric(merged_df['gene_expression'], errors='coerce')

# Iterate over each SNP column in the genotype data (independent variables)
results = {}
for snp in geno_df_filtered.columns:
    X = pd.to_numeric(merged_df[snp], errors='coerce')  # Convert SNP data to numeric
    X = sm.add_constant(X)  # Add an intercept for the linear regression
    
    # Drop rows with missing or invalid data (NaN)
    valid_data = pd.concat([y, X], axis=1).dropna()
    
    # Run the regression only if valid data exists
    if len(valid_data) > 0:
        model = sm.OLS(valid_data['gene_expression'], valid_data.iloc[:, 1:]).fit()  # Use .iloc to access predictors
        
        # Store the result for this SNP
        results[snp] = {
            'p-value': model.pvalues.iloc[1],  # Use .iloc to access the p-value for the SNP
            'beta': model.params.iloc[1],  # Use .iloc to access the beta coefficient for the SNP
            'r_squared': model.rsquared  # R-squared value
        }

# Convert results to a DataFrame for easier analysis
results_df = pd.DataFrame(results).transpose()

# Sort by p-value to find significant eQTLs
significant_eqtls = results_df.sort_values('p-value').head()
print("Most Significant Results:")
print(significant_eqtls)
print("\nAll Results:")
print(results_df)
# Out:
# Most Significant Results:
#             p-value      beta  r_squared
# rs4970420  0.004872 -0.016493   0.022943
# rs9442373  0.030045  0.010051   0.013688
# rs3748594  0.038706 -0.023893   0.012437
# rs3748593  0.052245 -0.022778   0.010973
# rs6696281  0.071271 -0.017948   0.009482
#
# All Results:
#              p-value      beta  r_squared
# rs3094315   0.179067 -0.008622   0.005273
# rs3131972   0.150053 -0.009219   0.006048
# rs3131969   0.365582 -0.006137   0.002394
# rs1048488   0.208763 -0.007981   0.004616
# rs3115850   0.223496 -0.007717   0.004330
# ...              ...       ...        ...
# rs1536168   0.104462 -0.018155   0.007689
# rs3737717   0.942082 -0.001428   0.000015
# rs12103     0.541356 -0.003543   0.001092
# rs12142199  0.302081 -0.005895   0.003114
# rs34054191  0.759153 -0.003741   0.000275
#
# [161 rows x 3 columns]

# %%
# adjust the results for plotting purposes
results_df['neg_log10_p'] = -np.log10(results_df['p-value'])
results_df1 = pd.merge(results_df, snps_in_window, left_index=True, right_on='snp')

# %%
# Create a locus zoom plot to look at results
# Set the aesthetics for the plot
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=results_df1, x='pos', y='neg_log10_p', color='blue', s=100)

# Adding labels and title
plt.title('LocusZoom Plot of eQTL Analysis', fontsize=16)
plt.xlabel('Genomic Coordinate (bp)', fontsize=14)
plt.ylabel('-log10(p-value)', fontsize=14)

# Adding a horizontal line for significance threshold (e.g., p < 0.05)
significance_threshold = -np.log10(0.05)
plt.axhline(y=significance_threshold, color='red', linestyle='--', label='p < 0.05')

# Customize x-axis limits (optional)
plt.xlim([results_df1['pos'].min() - 50000, results_df1['pos'].max() + 50000])

# Add legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# We will now repeat some of the process from above to transition to using chromosome 22
# This will help us in terms of size and time
bim, fam, G = pdpl.read_plink("EUR.22.test/1000G.EUR.22")

# This file contains the gene expression data we will be using
gene_expr = pd.read_csv('GD462.GeneQuantRPKM.50FN.samplename.resk10.txt.gz', compression='gzip', sep='\t')

# We also want to grab the gene annotations
with gzip.open("gene_annot.txt.gz", "rt") as f:
    # Read the file content into a pandas DataFrame
    gene_annotations = pd.read_csv(f, sep="\t")
    
# We want to combine the files so that we have users as rows, and their snps as columns
geno_df = pd.DataFrame(G.compute().transpose())
geno_df.columns = bim['snp']  # Use SNP IDs as columns
geno_df.index = fam['iid']  # Use individual IDs as rows

# Transpose gene expression data so that individual IDs are in the index as well
gene_expr_t = gene_expr.set_index('Gene_Symbol').transpose()

# The data isn't always consistent across all the files, so we want to only pull data we have all the information for
# Extract the individual IDs that match those in fam['iid']
gene_expr_t.index.name = 'iid'
matching_ids = gene_expr_t.index.intersection(fam['iid'])

# Filter both dataframes to only include these matching IDs
geno_df_filtered = geno_df.loc[matching_ids]
gene_expr_filtered = gene_expr_t.loc[matching_ids]
# Out:
# Mapping files: 100%|██████████| 3/3 [00:00<00:00, 51.24it/s]

# %%
# We will ramp up the process above, performing the analysis on a whole chromosome
# I have selected chromosome 14 for our test
chromosome = "22"
chr14_genes = gene_expr[gene_expr['Chr'] == chromosome]['Gene_Symbol']

# Initialize a list to store results for each SNP and gene as rows
chr14_results_list = []

for the_gene in chr14_genes:
    gene_info = gene_expr[gene_expr['Gene_Symbol'] == the_gene]
    snps_in_window = bim[(bim['chrom'] == chromosome) & 
                         (bim['pos'] >= int(gene_info['Coord'].iloc[0])-500000) & 
                         (bim['pos'] <= int(gene_info['Coord'].iloc[0])+500000)]
    
    # Get the SNP IDs from the filtered SNPs
    snp_ids = snps_in_window['snp'].values

    # Filter the genotype DataFrame for the SNPs in the window
    genotype_data_window = geno_df.loc[:, snp_ids]
    
    # Filter both dataframes to only include matching IDs
    geno_df_filtered = genotype_data_window.loc[matching_ids]
    gene_expr_filtered = gene_expr_t.loc[matching_ids]

    # Filter the gene expression data for the gene of interest
    gene_expr_filtered = gene_expr_t.loc[matching_ids, the_gene]

    # Merge the gene expression data with genotype data
    merged_df = pd.concat([gene_expr_filtered, geno_df_filtered], axis=1)

    # Rename the gene expression column for clarity
    merged_df.rename(columns={the_gene: 'gene_expression'}, inplace=True)
    
    # Ensure gene expression values are numeric
    y = pd.to_numeric(merged_df['gene_expression'], errors='coerce')

    for snp in geno_df_filtered.columns:
        X = pd.to_numeric(merged_df[snp], errors='coerce')  # Convert SNP data to numeric
        X = sm.add_constant(X)  # Add an intercept for the linear regression
    
        # Drop rows with missing or invalid data (NaN)
        valid_data = pd.concat([y, X], axis=1).dropna()
    
        # Run the regression only if valid data exists
        if len(valid_data) > 0:
            model = sm.OLS(valid_data['gene_expression'], valid_data.iloc[:, 1:]).fit()  # Use .iloc to access predictors

            if len(model.pvalues) > 1:
                # Append results for this SNP as a row in the results list
                chr14_results_list.append({
                    'Gene': the_gene,
                    'SNP': snp,
                    'p-value': model.pvalues.iloc[1],
                    'beta': model.params.iloc[1],
                    'r_squared': model.rsquared
                })
            else:
                print(f"Insufficient model output for SNP {snp}, skipping.")
                
    print(the_gene + ' completed')

# Convert the list of results into a DataFrame
chr14_results_df = pd.DataFrame(chr14_results_list)
# Out:
# ENSG00000249263.2 completed
# ENSG00000224688.1 completed
# ENSG00000075240.12 completed
# ENSG00000099937.6 completed
# ENSG00000099998.12 completed
# ENSG00000093072.10 completed
# ENSG00000185838.9 completed
# ENSG00000226085.2 completed
# ENSG00000100427.11 completed
# ENSG00000100344.6 completed
# ENSG00000040608.9 completed
# ENSG00000183741.7 completed
# ENSG00000230344.2 completed
# ENSG00000161132.6 completed
# ENSG00000099910.12 completed
# ENSG00000099942.8 completed
# ENSG00000231993.1 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100276.8 completed
# ENSG00000206140.5 completed
# ENSG00000100116.11 completed
# ENSG00000213888.2 completed
# ENSG00000197077.7 completed
# ENSG00000185651.10 completed
# ENSG00000100083.14 completed
# ENSG00000100031.14 completed
# ENSG00000240122.1 completed
# ENSG00000131100.8 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000242156.1 completed
# ENSG00000128254.9 completed
# ENSG00000234630.1 completed
# ENSG00000100077.7 completed
# ENSG00000239900.4 completed
# ENSG00000128191.9 completed
# ENSG00000253239.1 completed
# ENSG00000128185.5 completed
# ENSG00000233995.1 completed
# ENSG00000161180.5 completed
# ENSG00000228274.1 completed
# ENSG00000182257.5 completed
# ENSG00000099940.6 completed
# ENSG00000260708.1 completed
# ENSG00000260924.1 completed
# ENSG00000175329.7 completed
# ENSG00000215456.5 completed
# ENSG00000100028.7 completed
# ENSG00000100364.13 completed
# ENSG00000070413.12 completed
# ENSG00000167074.9 completed
# ENSG00000198911.6 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000159873.5 completed
# ENSG00000128340.10 completed
# ENSG00000254413.4 completed
# ENSG00000100181.15 completed
# ENSG00000227484.1 completed
# ENSG00000183172.6 completed
# ENSG00000184708.11 completed
# ENSG00000100029.12 completed
# ENSG00000100342.15 completed
# ENSG00000100401.14 completed
# ENSG00000211685.1 completed
# ENSG00000100353.12 completed
# ENSG00000225450.1 completed
# ENSG00000186716.14 completed
# ENSG00000075234.12 completed
# ENSG00000182351.6 completed
# ENSG00000128322.6 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000100320.16 completed
# ENSG00000241973.6 completed
# ENSG00000100024.9 completed
# ENSG00000099889.9 completed
# ENSG00000100154.10 completed
# ENSG00000100106.14 completed
# ENSG00000128294.10 completed
# ENSG00000100380.7 completed
# ENSG00000100271.11 completed
# ENSG00000261251.1 completed
# ENSG00000128165.7 completed
# ENSG00000159496.9 completed
# ENSG00000100316.11 completed
# ENSG00000253818.1 completed
# ENSG00000221890.2 completed
# ENSG00000128218.7 completed
# ENSG00000128311.8 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000186998.11 completed
# ENSG00000196431.3 completed
# ENSG00000215771.2 completed
# ENSG00000183473.5 completed
# ENSG00000183530.9 completed
# ENSG00000184319.11 completed
# ENSG00000130489.8 completed
# ENSG00000184076.9 completed
# ENSG00000100403.10 completed
# ENSG00000100099.14 completed
# ENSG00000182541.12 completed
# ENSG00000241360.1 completed
# ENSG00000177989.8 completed
# ENSG00000169548.3 completed
# ENSG00000133454.11 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000183762.8 completed
# ENSG00000185386.10 completed
# ENSG00000100417.7 completed
# ENSG00000100142.8 completed
# ENSG00000100138.9 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000186575.12 completed
# ENSG00000184470.13 completed
# ENSG00000214093.3 completed
# ENSG00000214076.3 completed
# ENSG00000169184.5 completed
# ENSG00000161133.12 completed
# ENSG00000183773.10 completed
# ENSG00000182858.7 completed
# ENSG00000100294.7 completed
# ENSG00000235617.1 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000198125.7 completed
# ENSG00000128309.11 completed
# ENSG00000184979.8 completed
# ENSG00000211651.2 completed
# ENSG00000215481.4 completed
# ENSG00000251267.1 completed
# ENSG00000100150.10 completed
# ENSG00000099953.5 completed
# ENSG00000241878.4 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100209.5 completed
# ENSG00000213279.2 completed
# ENSG00000248603.1 completed
# ENSG00000100418.7 completed
# ENSG00000100003.12 completed
# ENSG00000100027.10 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000233388.1 completed
# ENSG00000128253.9 completed
# ENSG00000100151.11 completed
# ENSG00000230701.1 completed
# ENSG00000100304.10 completed
# ENSG00000099904.11 completed
# ENSG00000243762.1 completed
# ENSG00000177663.8 completed
# ENSG00000231565.1 completed
# ENSG00000069998.8 completed
# ENSG00000128408.7 completed
# ENSG00000254709.1 completed
# ENSG00000198832.6 completed
# ENSG00000243156.2 completed
# ENSG00000211660.3 completed
# ENSG00000211637.2 completed
# ENSG00000223579.1 completed
# ENSG00000239282.3 completed
# ENSG00000241990.1 completed
# ENSG00000100218.7 completed
# ENSG00000248751.2 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100263.9 completed
# ENSG00000237472.1 completed
# ENSG00000213727.3 completed
# ENSG00000188636.3 completed
# ENSG00000234252.1 completed
# ENSG00000205643.6 completed
# ENSG00000100221.6 completed
# ENSG00000251322.2 completed
# ENSG00000211662.2 completed
# ENSG00000100227.12 completed
# ENSG00000205593.5 completed
# ENSG00000100345.14 completed
# ENSG00000198477.3 completed
# ENSG00000258242.1 completed
# ENSG00000215193.5 completed
# ENSG00000100385.8 completed
# ENSG00000161103.6 completed
# ENSG00000184949.9 completed
# ENSG00000100109.11 completed
# ENSG00000176177.9 completed
# ENSG00000242259.3 completed
# ENSG00000223875.1 completed
# ENSG00000025770.13 completed
# ENSG00000184702.12 completed
# ENSG00000133466.9 completed
# ENSG00000100101.12 completed
# ENSG00000100299.12 completed
# ENSG00000100298.11 completed
# ENSG00000100300.12 completed
# ENSG00000183506.10 completed
# ENSG00000236670.1 completed
# ENSG00000223730.1 completed
# ENSG00000184983.4 completed
# ENSG00000222037.5 completed
# ENSG00000133460.13 completed
# ENSG00000100201.13 completed
# ENSG00000230712.2 completed
# ENSG00000100216.4 completed
# ENSG00000182057.4 completed
# ENSG00000253120.1 completed
# ENSG00000228599.1 completed
# ENSG00000206203.3 completed
# ENSG00000211667.2 completed
# ENSG00000211664.2 completed
# ENSG00000015475.14 completed
# ENSG00000189060.3 completed
# ENSG00000226142.2 completed
# ENSG00000073150.8 completed
# ENSG00000212939.2 completed
# ENSG00000196934.2 completed
# ENSG00000100242.11 completed
# ENSG00000100393.9 completed
# ENSG00000184792.11 completed
# ENSG00000100100.7 completed
# ENSG00000230769.1 completed
# ENSG00000203606.3 completed
# ENSG00000241484.5 completed
# ENSG00000214727.2 completed
# ENSG00000230513.1 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100280.12 completed
# ENSG00000218537.1 completed
# ENSG00000183628.7 completed
# ENSG00000235568.2 completed
# ENSG00000225335.1 completed
# ENSG00000100324.8 completed
# ENSG00000228315.5 completed
# ENSG00000100372.10 completed
# ENSG00000230071.1 completed
# ENSG00000211652.2 completed
# ENSG00000215270.3 completed
# ENSG00000100014.13 completed
# ENSG00000100429.13 completed
# ENSG00000198355.4 completed
# ENSG00000189306.6 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100219.10 completed
# ENSG00000234009.1 completed
# ENSG00000100321.10 completed
# ENSG00000100075.5 completed
# ENSG00000188130.8 completed
# ENSG00000100365.10 completed
# ENSG00000228839.1 completed
# ENSG00000025708.8 completed
# ENSG00000260655.1 completed
# ENSG00000185339.4 completed
# ENSG00000184164.10 completed
# ENSG00000211665.2 completed
# ENSG00000183785.9 completed
# ENSG00000188424.4 completed
# ENSG00000237977.1 completed
# ENSG00000235954.2 completed
# ENSG00000237668.1 completed
# ENSG00000224334.1 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000100302.6 completed
# ENSG00000213857.3 completed
# ENSG00000185022.7 completed
# ENSG00000226885.1 completed
# ENSG00000226328.1 completed
# ENSG00000254030.1 completed
# ENSG00000188078.5 completed
# ENSG00000099954.13 completed
# ENSG00000133424.14 completed
# ENSG00000205560.8 completed
# ENSG00000231466.2 completed
# ENSG00000161149.7 completed
# ENSG00000206066.3 completed
# ENSG00000182502.2 completed
# ENSG00000182841.8 completed
# ENSG00000235513.1 completed
# ENSG00000183307.3 completed
# ENSG00000206028.1 completed
# ENSG00000100379.13 completed
# ENSG00000211655.2 completed
# ENSG00000197210.6 completed
# ENSG00000202058.1 completed
# ENSG00000100104.7 completed
# ENSG00000250318.1 completed
# ENSG00000211670.2 completed
# ENSG00000187792.3 completed
# ENSG00000100422.9 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000237406.1 completed
# ENSG00000133422.7 completed
# ENSG00000255594.1 completed
# ENSG00000230481.1 completed
# ENSG00000100239.10 completed
# ENSG00000230319.1 completed
# ENSG00000243811.2 completed
# ENSG00000128342.4 completed
# ENSG00000100395.10 completed
# ENSG00000100241.14 completed
# ENSG00000237438.1 completed
# ENSG00000166897.9 completed
# ENSG00000225783.2 completed
# ENSG00000234764.1 completed
# ENSG00000205704.5 completed
# ENSG00000178026.8 completed
# ENSG00000225225.1 completed
# ENSG00000128383.8 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000225465.4 completed
# ENSG00000184068.2 completed
# ENSG00000241838.2 completed
# ENSG00000237476.1 completed
# ENSG00000226450.2 completed
# ENSG00000100196.6 completed
# ENSG00000183864.4 completed
# ENSG00000240072.1 completed
# ENSG00000100124.7 completed
# ENSG00000249590.3 completed
# ENSG00000133519.8 completed
# ENSG00000185252.13 completed
# ENSG00000093010.7 completed
# ENSG00000260613.1 completed
# ENSG00000161179.9 completed
# ENSG00000238120.1 completed
# ENSG00000225282.1 completed
# ENSG00000128268.11 completed
# ENSG00000215498.3 completed
# ENSG00000128262.4 completed
# ENSG00000128274.10 completed
# ENSG00000138867.12 completed
# ENSG00000224806.2 completed
# ENSG00000100139.9 completed
# ENSG00000223704.1 completed
# ENSG00000225098.1 completed
# ENSG00000215513.4 completed
# ENSG00000172346.9 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000185340.10 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000233080.2 completed
# ENSG00000100360.10 completed
# ENSG00000182824.6 completed
# ENSG00000169314.9 completed
# ENSG00000230107.1 completed
# ENSG00000185065.6 completed
# ENSG00000100092.14 completed
# ENSG00000236850.3 completed
# ENSG00000099985.3 completed
# ENSG00000100129.11 completed
# ENSG00000100220.7 completed
# ENSG00000253352.3 completed
# ENSG00000099901.11 completed
# ENSG00000100105.13 completed
# ENSG00000197182.8 completed
# ENSG00000231369.1 completed
# ENSG00000225774.1 completed
# ENSG00000226287.3 completed
# ENSG00000248405.5 completed
# ENSG00000100376.7 completed
# ENSG00000128285.4 completed
# ENSG00000100056.7 completed
# ENSG00000214526.3 completed
# ENSG00000237214.2 completed
# ENSG00000242114.1 completed
# ENSG00000070371.11 completed
# ENSG00000184624.4 completed
# ENSG00000215012.4 completed
# ENSG00000244486.2 completed
# ENSG00000172404.4 completed
# ENSG00000211669.2 completed
# ENSG00000187045.12 completed
# ENSG00000211644.2 completed
# ENSG00000211642.2 completed
# ENSG00000211675.2 completed
# ENSG00000228923.1 completed
# ENSG00000213923.5 completed
# ENSG00000100167.15 completed
# ENSG00000225971.1 completed
# ENSG00000234965.1 completed
# ENSG00000100350.10 completed
# ENSG00000240906.2 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000100292.12 completed
# ENSG00000243453.1 completed
# ENSG00000259421.1 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100296.9 completed
# ENSG00000213683.3 completed
# ENSG00000100058.7 completed
# ENSG00000177096.4 completed
# ENSG00000100122.5 completed
# ENSG00000211673.2 completed
# ENSG00000235237.1 completed
# ENSG00000249288.1 completed
# ENSG00000196622.5 completed
# ENSG00000211679.2 completed
# ENSG00000214125.2 completed
# ENSG00000093100.12 completed
# ENSG00000223350.2 completed
# ENSG00000196576.9 completed
# ENSG00000235704.1 completed
# ENSG00000225544.1 completed
# ENSG00000211656.2 completed
# ENSG00000100097.7 completed
# ENSG00000217442.3 completed
# ENSG00000093000.13 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000100281.9 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000100297.7 completed
# ENSG00000205559.3 completed
# ENSG00000211659.2 completed
# ENSG00000261188.1 completed
# ENSG00000236540.1 completed
# ENSG00000100206.4 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100285.8 completed
# ENSG00000211638.2 completed
# ENSG00000128159.7 completed
# ENSG00000237347.1 completed
# ENSG00000227367.1 completed
# ENSG00000256872.1 completed
# ENSG00000213707.2 completed
# ENSG00000100290.2 completed
# ENSG00000169662.8 completed
# ENSG00000133475.12 completed
# ENSG00000100060.12 completed
# ENSG00000133433.6 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000237015.1 completed
# ENSG00000235111.1 completed
# ENSG00000100348.5 completed
# ENSG00000254835.1 completed
# ENSG00000130638.10 completed
# ENSG00000211668.2 completed
# ENSG00000099974.7 completed
# ENSG00000100330.10 completed
# ENSG00000167077.7 completed
# ENSG00000183569.12 completed
# ENSG00000100258.12 completed
# ENSG00000224856.1 completed
# ENSG00000198089.9 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000182944.13 completed
# ENSG00000224623.1 completed
# ENSG00000169668.7 completed
# ENSG00000070010.12 completed
# ENSG00000233899.1 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000226471.1 completed
# ENSG00000235485.1 completed
# ENSG00000100162.10 completed
# ENSG00000100368.8 completed
# ENSG00000225720.2 completed
# ENSG00000099992.11 completed
# ENSG00000178248.10 completed
# ENSG00000234735.1 completed
# ENSG00000100426.5 completed
# ENSG00000226912.1 completed
# ENSG00000234503.1 completed
# ENSG00000211658.2 completed
# ENSG00000213790.2 completed
# ENSG00000182902.8 completed
# ENSG00000178803.6 completed
# ENSG00000186654.15 completed
# ENSG00000235231.3 completed
# ENSG00000099957.11 completed
# ENSG00000211677.2 completed
# ENSG00000228050.1 completed
# ENSG00000185837.3 completed
# ENSG00000128346.6 completed
# ENSG00000128271.12 completed
# ENSG00000237407.1 completed
# ENSG00000196236.6 completed
# ENSG00000099995.12 completed
# ENSG00000239713.3 completed
# ENSG00000184381.11 completed
# ENSG00000196588.8 completed
# ENSG00000184208.10 completed
# ENSG00000100412.10 completed
# ENSG00000100068.7 completed
# ENSG00000249310.2 completed
# ENSG00000183246.6 completed
# ENSG00000188677.9 completed
# ENSG00000211649.2 completed
# ENSG00000227188.1 completed
# ENSG00000138964.10 completed
# ENSG00000197421.5 completed
# ENSG00000232710.1 completed
# ENSG00000215347.3 completed
# ENSG00000244491.1 completed
# ENSG00000100253.8 completed
# ENSG00000180957.12 completed
# ENSG00000099991.11 completed
# ENSG00000236650.1 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000183579.10 completed
# ENSG00000225528.1 completed
# ENSG00000211671.2 completed
# ENSG00000100311.12 completed
# ENSG00000100319.11 completed
# ENSG00000223461.1 completed
# ENSG00000167065.9 completed
# ENSG00000211648.2 completed
# ENSG00000211645.2 completed
# ENSG00000100034.8 completed
# ENSG00000170638.5 completed
# ENSG00000008735.10 completed
# ENSG00000197549.5 completed
# ENSG00000232545.1 completed
# ENSG00000093009.5 completed
# ENSG00000261202.1 completed
# ENSG00000100225.13 completed
# ENSG00000100226.11 completed
# ENSG00000100147.8 completed
# ENSG00000100288.15 completed
# ENSG00000128394.12 completed
# ENSG00000215268.3 completed
# ENSG00000075275.12 completed
# ENSG00000232346.1 completed
# ENSG00000100030.9 completed
# ENSG00000100023.12 completed
# ENSG00000185686.13 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000100336.13 completed
# ENSG00000211666.2 completed
# ENSG00000224124.2 completed
# ENSG00000187860.6 completed
# ENSG00000224086.3 completed
# ENSG00000100243.15 completed
# ENSG00000100351.11 completed
# ENSG00000100416.8 completed
# ENSG00000240529.1 completed
# ENSG00000235989.2 completed
# ENSG00000220248.1 completed
# ENSG00000211653.2 completed
# ENSG00000211640.2 completed
# ENSG00000185608.4 completed
# ENSG00000073169.9 completed
# ENSG00000100055.14 completed
# ENSG00000128203.6 completed
# ENSG00000198792.7 completed
# ENSG00000234353.2 completed
# ENSG00000229598.1 completed
# ENSG00000183963.12 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000221963.4 completed
# ENSG00000244509.2 completed
# ENSG00000198567.5 completed
# ENSG00000100084.9 completed
# ENSG00000100197.15 completed
# ENSG00000159958.3 completed
# ENSG00000230203.1 completed
# ENSG00000128283.6 completed
# ENSG00000187979.3 completed
# ENSG00000224003.1 completed
# ENSG00000206195.4 completed
# ENSG00000215544.6 completed
# ENSG00000128228.4 completed
# ENSG00000128272.10 completed
# ENSG00000205702.5 completed
# ENSG00000056487.11 completed
# ENSG00000099999.9 completed
# ENSG00000079974.13 completed
# ENSG00000226954.1 completed
# ENSG00000169635.5 completed
# ENSG00000240972.1 completed
# ENSG00000206142.4 completed
# ENSG00000099968.13 completed
# ENSG00000099899.9 completed
# ENSG00000227117.2 completed
# ENSG00000054611.9 completed
# ENSG00000183597.11 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000240293.1 completed
# ENSG00000233903.1 completed
# ENSG00000227370.1 completed
# ENSG00000224435.2 completed
# ENSG00000211650.2 completed
# ENSG00000188064.5 completed
# ENSG00000237037.3 completed
# ENSG00000250479.3 completed
# ENSG00000100359.14 completed
# ENSG00000196419.7 completed
# ENSG00000130487.4 completed
# ENSG00000233739.1 completed
# ENSG00000244627.1 completed
# ENSG00000099949.13 completed
# ENSG00000244752.2 completed
# ENSG00000184674.7 completed
# ENSG00000100347.10 completed
# ENSG00000239435.1 completed
# ENSG00000227895.3 completed
# ENSG00000099956.12 completed
# ENSG00000227201.2 completed
# ENSG00000100246.7 completed
# ENSG00000179750.11 completed
# ENSG00000128335.9 completed
# ENSG00000100399.11 completed
# ENSG00000232926.1 completed
# ENSG00000128298.11 completed
# ENSG00000186951.11 completed
# ENSG00000100033.11 completed
# ENSG00000242247.5 completed
# ENSG00000235776.1 completed
# ENSG00000077935.12 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000128284.15 completed
# ENSG00000185721.6 completed
# ENSG00000099994.10 completed
# ENSG00000099977.9 completed
# ENSG00000229107.2 completed
# ENSG00000198951.6 completed
# ENSG00000100387.8 completed
# ENSG00000100036.11 completed
# ENSG00000172250.10 completed
# ENSG00000249222.1 completed
# ENSG00000100211.6 completed
# ENSG00000230149.2 completed
# ENSG00000184436.7 completed
# ENSG00000183038.9 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000128250.5 completed
# ENSG00000100266.11 completed
# ENSG00000099984.6 completed
# ENSG00000227755.1 completed
# ENSG00000185133.9 completed
# ENSG00000100307.8 completed
# ENSG00000075218.13 completed
# ENSG00000206176.5 completed
# ENSG00000215464.3 completed
# ENSG00000100425.13 completed
# ENSG00000100228.7 completed
# ENSG00000240591.1 completed
# ENSG00000244625.1 completed
# ENSG00000128266.6 completed
# ENSG00000188511.8 completed
# ENSG00000186976.10 completed
# ENSG00000100354.14 completed
# ENSG00000187051.4 completed
# ENSG00000128242.8 completed
# ENSG00000100207.14 completed
# ENSG00000215493.3 completed
# ENSG00000100410.3 completed
# ENSG00000130943.5 completed
# ENSG00000216522.3 completed
# ENSG00000211663.2 completed
# ENSG00000100413.12 completed
# Insufficient model output for SNP rs5999980, skipping.
# ENSG00000100284.13 completed
# ENSG00000138942.9 completed
# ENSG00000253234.1 completed
# ENSG00000211639.2 completed
# ENSG00000100038.14 completed
# ENSG00000183066.10 completed
# ENSG00000230736.2 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000100314.3 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000183765.14 completed
# ENSG00000128245.9 completed
# ENSG00000099917.12 completed
# ENSG00000244425.1 completed
# ENSG00000236325.1 completed
# ENSG00000241528.1 completed
# ENSG00000205853.5 completed
# ENSG00000128276.6 completed
# Insufficient model output for SNP rs8142085, skipping.
# ENSG00000184117.7 completed
# ENSG00000260065.1 completed
# ENSG00000100121.8 completed
# ENSG00000099958.10 completed
# ENSG00000233360.2 completed
# ENSG00000100335.8 completed
# ENSG00000100325.10 completed

# %%
chr14_results_df.to_csv('chr22_eqtl_data.txt', sep='\t', index=False)

# %%
sum(chr14_results_df['p-value'] < (0.05/(387*633)))
# Out:
# 1333

# %%
g2 = chr14_results_df[chr14_results_df['Gene'] == 'ENSG00000100376.7']

# %%
sum(g2['r_squared'] > 0.1)
# Out:
# 19

# %%
chr14_results_df['p-value'].sort_values()
# Out:
# 143920    3.256798e-87
# 143953    3.509309e-86
# 143956    3.509309e-86
# 143955    3.509309e-86
# 143941    3.509309e-86
#               ...
# 116899    9.999667e-01
# 155984    9.999720e-01
# 104004    9.999794e-01
# 138481    9.999887e-01
# 177617    9.999993e-01
# Name: p-value, Length: 270853, dtype: float64
